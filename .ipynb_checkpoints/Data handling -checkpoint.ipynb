# %%
with open('example.txt', 'r') as file:
    content = file.read()
    print (content)
# Out:
# Test 1
# Test 2
# ok

# %%
with open('example.txt', 'r') as file:
    content = file.readline()
    print (content)
# Out:
# Test 1

# %%
import csv
with open('students.csv', 'r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        print(row)
# Out:
# ['Name', 'Age', 'Grade']
# ['Alice', '21', 'A']
# ['Bob', '22', 'F']
# ['Charlie', '18', 'B']
# ['David', '21', 'A']
# ['Eve', '20', 'A']
# ['Fiona', '18', 'C']
# ['George', '19', 'A']
# ['Hannah', '20', 'C']
# ['Isla', '22', 'A']
# ['Jack', '21', 'B']
# ['Alice', '20', 'C']
# ['Bob', '20', 'C']
# ['Charlie', '18', 'C']
# ['David', '20', 'A']
# ['Eve', '21', 'B']
# ['Fiona', '19', 'C']
# ['George', '18', 'F']
# ['Hannah', '19', 'B']
# ['Isla', '19', 'B']
# ['Jack', '18', 'F']
# ['Alice', '18', 'F']
# ['Bob', '18', 'F']
# ['Charlie', '18', 'C']
# ['David', '18', 'F']
# ['Eve', '20', 'B']
# ['Fiona', '19', 'B']
# ['George', '21', 'D']
# ['Hannah', '19', 'B']
# ['Isla', '19', 'B']
# ['Jack', '18', 'F']
# ['Alice', '19', 'B']
# ['Bob', '20', 'B']
# ['Charlie', '22', 'D']
# ['David', '20', 'C']
# ['Eve', '19', 'A']
# ['Fiona', '20', 'F']
# ['George', '21', 'F']
# ['Hannah', '22', 'F']
# ['Isla', '21', 'F']
# ['Jack', '19', 'F']
# ['Alice', '20', 'C']
# ['Bob', '22', 'F']
# ['Charlie', '21', 'C']
# ['David', '21', 'C']
# ['Eve', '22', 'A']
# ['Fiona', '20', 'B']
# ['George', '20', 'D']
# ['Hannah', '21', 'F']
# ['Isla', '22', 'B']
# ['Jack', '21', 'B']
# ['Alice', '22', 'B']
# ['Bob', '20', 'C']
# ['Charlie', '21', 'A']
# ['David', '22', 'F']
# ['Eve', '19', 'A']
# ['Fiona', '19', 'F']
# ['George', '21', 'D']
# ['Hannah', '20', 'B']
# ['Isla', '18', 'A']
# ['Jack', '18', 'D']
# ['Alice', '18', 'C']
# ['Bob', '20', 'C']
# ['Charlie', '19', 'C']
# ['David', '20', 'F']
# ['Eve', '18', 'D']
# ['Fiona', '22', 'A']
# ['George', '18', 'D']
# ['Hannah', '18', 'C']
# ['Isla', '20', 'B']
# ['Jack', '20', 'F']
# ['Alice', '22', 'A']
# ['Bob', '20', 'F']
# ['Charlie', '22', 'C']
# ['David', '18', 'A']
# ['Eve', '20', 'F']
# ['Fiona', '19', 'A']
# ['George', '18', 'F']
# ['Hannah', '19', 'B']
# ['Isla', '18', 'D']
# ['Jack', '22', 'B']
# ['Alice', '19', 'A']
# ['Bob', '19', 'D']
# ['Charlie', '19', 'A']
# ['David', '20', 'F']
# ['Eve', '19', 'B']
# ['Fiona', '20', 'C']
# ['George', '22', 'A']
# ['Hannah', '19', 'D']
# ['Isla', '19', 'C']
# ['Jack', '21', 'C']
# ['Alice', '18', 'A']
# ['Bob', '19', 'B']
# ['Charlie', '22', 'F']
# ['David', '22', 'A']
# ['Eve', '21', 'C']
# ['Fiona', '19', 'F']
# ['George', '18', 'C']
# ['Hannah', '22', 'F']
# ['Isla', '18', 'F']
# ['Jack', '20', 'D']

# %%
import csv
with open('students.csv', 'r') as c_file:
    csv_reader = csv.DictReader(c_file)#'c_'for easier to differentiate between another, if x put also never mind
    for row in csv_reader:
        print(row['Name'])
# Out:
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack

# %%
import csv
with open('students.csv', 'r') as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        print(row['Name'])
# Out:
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack
# Alice
# Bob
# Charlie
# David
# Eve
# Fiona
# George
# Hannah
# Isla
# Jack

# %%
import csv
with open('students.csv', 'r') as c_file:
    csv_reader = csv.DictReader(c_file)
    for row in csv_reader:
        print(row['Grade'])
# Out:
# A
# F
# B
# A
# A
# C
# A
# C
# A
# B
# C
# C
# C
# A
# B
# C
# F
# B
# B
# F
# F
# F
# C
# F
# B
# B
# D
# B
# B
# F
# B
# B
# D
# C
# A
# F
# F
# F
# F
# F
# C
# F
# C
# C
# A
# B
# D
# F
# B
# B
# B
# C
# A
# F
# A
# F
# D
# B
# A
# D
# C
# C
# C
# F
# D
# A
# D
# C
# B
# F
# A
# F
# C
# A
# F
# A
# F
# B
# D
# B
# A
# D
# A
# F
# B
# C
# A
# D
# C
# C
# A
# B
# F
# A
# C
# F
# C
# F
# F
# D

# %%
with open('output.txt', 'w') as file:
    file.write('\nHello, Python!')
    file.write('\nHello, World!')

# %% [markdown]
# # #Exercise 1

# %%
def filter_students(input_file, output_file): #can add on "import csv" at the first row haha
    with open(input_file, mode='r') as file:
        csv_reader = csv.DictReader(file)
        filtered_students = [student for student in csv_reader if student['Grade'] <= 'B']
        
    for student in filtered_students:
        student['Status'] = 'Passed' if student['Grade'] <= 'B' else 'Failed'
        
    fieldnames = ['Name', 'Age', 'Grade', 'Status']
    with open(output_file, mode='w', newline='') as new_file:
        writer = csv.DictWriter(new_file, fieldnames=fieldnames)
        
        writer.writeheader()
        writer.writerows(filtered_students)
        
input_filename = 'students.csv'
output_filename = 'top_students.csv'        
        
filter_students(input_filename, output_filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 19
#      16 input_filename = 'students.csv'
#      17 output_filename = 'top_students.csv'
# ---> 19 filter_students(input_filename, output_filename)
#
# Cell In[7], line 3, in filter_students(input_file, output_file)
#       1 def filter_students(input_file, output_file):
#       2     with open(input_file, mode='r') as file:
# ----> 3         csv_reader = csv.DictReader(file)
#       4         filtered_students = [student for student in csv_reader if student['Grade'] <= 'B']
#       6     for student in filtered_students:
#
# NameError: name 'csv' is not defined

# %% [markdown]
# # #Web Data Handling

# %%
import requests
api_url = "https://jian.sh/malaysia-api/state/v1/all.json"
response = requests.get(api_url)
malaysia_state_data = response.json()
print(malaysia_state_data)
# Out:
# [{'administrative_division': 'State of Malaysia', 'state': 'Johor', 'capital': 'Johor Bahru', 'royal_capital': 'Muar', 'population': 3794000, 'total_area': 19166, 'licence_plate_prefix': 'J', 'phone_area_code': '07, 06 (Muar & Tangkak)', 'abbreviation': 'JHR', 'ISO': 'MY-01', 'FIPS': 'MY01', 'HDI': 0.818, 'region': 'Peninsular Malaysia', 'head_of_state': 'Sultan', 'head_of_goverment': 'Menteri Besar'}, {'administrative_division': 'State of Malaysia', 'state': 'Kedah', 'capital': 'Alor Setar', 'royal_capital': 'Anak Bukit', 'population': 2194100, 'total_area': 9492, 'licence_plate_prefix': 'K', 'phone_area_code': '04', 'abbreviation': 'KDH', 'ISO': 'MY-02', 'FIPS': 'MY03', 'HDI': 0.802, 'region': 'Peninsular Malaysia', 'head_of_state': 'Sultan', 'head_of_goverment': 'Menteri Besar'}, {'administrative_division': 'State of Malaysia', 'state': 'Kelantan', 'capital': 'Kota Bharu', 'royal_capital': 'Kubang Kerian', 'population': 1928800, 'total_area': 15040, 'licence_plate_prefix': 'D', 'phone_area_code': '09', 'abbreviation': 'KTN', 'ISO': 'MY-03', 'FIPS': 'MY03', 'HDI': 0.772, 'region': 'Peninsular Malaysia', 'head_of_state': 'Sultan', 'head_of_goverment': 'Menteri Besar'}, {'administrative_division': 'State of Malaysia', 'state': 'Malacca', 'capital': 'Malacca City', 'royal_capital': '-', 'population': 937500, 'total_area': 1712, 'licence_plate_prefix': 'M', 'phone_area_code': '06', 'abbreviation': 'MLK', 'ISO': 'MY-04', 'FIPS': 'MY04', 'HDI': 0.828, 'region': 'Peninsular Malaysia', 'head_of_state': 'Yang di-Pertua Negeri (Governor)', 'head_of_goverment': 'Chief Minister'}, {'administrative_division': 'State of Malaysia', 'state': 'Negeri Sembilan', 'capital': 'Seremban', 'royal_capital': 'Seri Menanti', 'population': 1129100, 'total_area': 6658, 'licence_plate_prefix': 'N', 'phone_area_code': '06', 'abbreviation': 'NSN', 'ISO': 'MY-05', 'FIPS': 'MY05', 'HDI': 0.822, 'region': 'Peninsular Malaysia', 'head_of_state': 'Yang di-Pertua Negeri (Grand Ruler)', 'head_of_goverment': 'Menteri Besar'}, {'administrative_division': 'State of Malaysia', 'state': 'Pahang', 'capital': 'Kuantan', 'royal_capital': 'Pekan', 'population': 1684600, 'total_area': 35965, 'licence_plate_prefix': 'C', 'phone_area_code': '09, 03 (Genting Highlands), 05 (Cameron)', 'abbreviation': 'PHG', 'ISO': 'MY-06', 'FIPS': 'MY06', 'HDI': 0.797, 'region': 'Peninsular Malaysia', 'head_of_state': 'Sultan', 'head_of_goverment': 'Menteri Besar'}, {'administrative_division': 'State of Malaysia', 'state': 'Penang', 'capital': 'George Town', 'royal_capital': '-', 'population': 1774400, 'total_area': 1049, 'licence_plate_prefix': 'P', 'phone_area_code': '04', 'abbreviation': 'PNG', 'ISO': 'MY-07', 'FIPS': 'MY09', 'HDI': 0.838, 'region': 'Peninsular Malaysia', 'head_of_state': 'Yang di-Pertua Negeri (Governor)', 'head_of_goverment': 'Chief Minister'}, {'administrative_division': 'State of Malaysia', 'state': 'Perak', 'capital': 'Ipoh', 'royal_capital': 'Kuala Kangsar', 'population': 2508900, 'total_area': 21146, 'licence_plate_prefix': 'A', 'phone_area_code': '05', 'abbreviation': 'PRK', 'ISO': 'MY-08', 'FIPS': 'MY07', 'HDI': 0.809, 'region': 'Peninsular Malaysia', 'head_of_state': 'Sultan', 'head_of_goverment': 'Menteri Besar'}, {'administrative_division': 'State of Malaysia', 'state': 'Perlis', 'capital': 'Kangar', 'royal_capital': 'Arau', 'population': 255400, 'total_area': 819, 'licence_plate_prefix': 'R', 'phone_area_code': '04', 'abbreviation': 'PLS', 'ISO': 'MY-09', 'FIPS': 'MY08', 'HDI': 0.799, 'region': 'Peninsular Malaysia', 'head_of_state': 'Raja', 'head_of_goverment': 'Menteri Besar'}, {'administrative_division': 'State of Malaysia', 'state': 'Sabah', 'capital': 'Kota Kinabalu', 'royal_capital': '-', 'population': 3833000, 'total_area': 73621, 'licence_plate_prefix': 'S', 'phone_area_code': '087–089', 'abbreviation': 'SBH', 'ISO': 'MY-12', 'FIPS': 'MY16', 'HDI': 0.704, 'region': 'East Malaysia', 'head_of_state': 'Yang di-Pertua Negeri (Governor)', 'head_of_govermen ...

# %%
import requests
api_url = "https://jian.sh/malaysia-api/state/v1/all.json"
response = requests.get(api_url)
malaysia_state_data = response.json()

for state in malaysia_state_data:
    print(f"State: {state['state']}, Capital: {state['capital']}, Population: {state['population']}")
# Out:
# State: Johor, Capital: Johor Bahru, Population: 3794000
# State: Kedah, Capital: Alor Setar, Population: 2194100
# State: Kelantan, Capital: Kota Bharu, Population: 1928800
# State: Malacca, Capital: Malacca City, Population: 937500
# State: Negeri Sembilan, Capital: Seremban, Population: 1129100
# State: Pahang, Capital: Kuantan, Population: 1684600
# State: Penang, Capital: George Town, Population: 1774400
# State: Perak, Capital: Ipoh, Population: 2508900
# State: Perlis, Capital: Kangar, Population: 255400
# State: Sabah, Capital: Kota Kinabalu, Population: 3833000
# State: Sarawak, Capital: Kuching, Population: 2822200
# State: Selangor, Capital: Shah Alam, Population: 6555400
# State: Terengganu, Capital: Kuala Terengganu, Population: 1275100
# State: Kuala Lumpur, Capital: Kuala Lumpur, Population: 1746600
# State: Labuan, Capital: Victoria, Population: 100100
# State: Putrajaya, Capital: Putrajaya, Population: 116100

# %%
import requests
api_url = "https://jian.sh/malaysia-api/state/v1/all.json"
response = requests.get(api_url)
malaysia_state_data = response.json()

for state in malaysia_state_data:
    print(f"State: {state['state']}, Capital: {state['licence_plate_prefix']}")
# Out:
# State: Johor, Capital: J
# State: Kedah, Capital: K
# State: Kelantan, Capital: D
# State: Malacca, Capital: M
# State: Negeri Sembilan, Capital: N
# State: Pahang, Capital: C
# State: Penang, Capital: P
# State: Perak, Capital: A
# State: Perlis, Capital: R
# State: Sabah, Capital: S
# State: Sarawak, Capital: Q
# State: Selangor, Capital: B
# State: Terengganu, Capital: T
# State: Kuala Lumpur, Capital: W / V
# State: Labuan, Capital: L
# State: Putrajaya, Capital: F

# %% [markdown]
# ## Practice Exercise

# %%
state_populations = {'Johor': 3794000, 'Kedah': 2224400, 'Kelantan': 1938000}

def get_state_population():
  while True:
    state_name = input("Enter the name of a state: ")
    if state_name in state_populations:
        population = state_populations[state_name]
        print(f"Population of {state_name}: {population}")
        break
    else:
        print(f"{state_name} is not found in the data.")

get_state_population()
# Out:
# Enter the name of a state: selangor
# selangor is not found in the data.
# Enter the name of a state: Johor
# Population of Johor: 3794000

# %%
state_populations = {'Johor': 3794000, 'Kedah': 2224400, 'Kelantan': 1938000}

def get_state_population():
  while True:
    state_name = input("Enter the name of a state: ")
    if state_name in state_populations:
        population = state_populations[state_name]
        population_info = "Population of " + state_name + ": " + str(population)
        print(population_info)
        break
    else:
        population_info2 = state_name + "is not found in the data"
        print(population_info2)

get_state_population()
# Out:
# Enter the name of a state: Selangor
# Selangoris not found in the data
# Enter the name of a state: Johor
# Population of Johor: 3794000
